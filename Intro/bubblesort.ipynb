# %%
def bubsort(li):
    for i in range(len(li)-1):
        print(li)
        for j in range(len(li)-1-i):
            # print(li[j],li[j+1])
            if (li[j]>li[j+1]):
                li[j],li[j+1]=li[j+1],li[j]

# %%
li =[232,999,7,81,2,3,45,6,4,5,3,1,2,4,3,34,343,4,545,887]
# li=[4,2,1,5,6]
bubsort(li)
# Out:
# [232, 999, 7, 81, 2, 3, 45, 6, 4, 5, 3, 1, 2, 4, 3, 34, 343, 4, 545, 887]
# [232, 7, 81, 2, 3, 45, 6, 4, 5, 3, 1, 2, 4, 3, 34, 343, 4, 545, 887, 999]
# [7, 81, 2, 3, 45, 6, 4, 5, 3, 1, 2, 4, 3, 34, 232, 4, 343, 545, 887, 999]
# [7, 2, 3, 45, 6, 4, 5, 3, 1, 2, 4, 3, 34, 81, 4, 232, 343, 545, 887, 999]
# [2, 3, 7, 6, 4, 5, 3, 1, 2, 4, 3, 34, 45, 4, 81, 232, 343, 545, 887, 999]
# [2, 3, 6, 4, 5, 3, 1, 2, 4, 3, 7, 34, 4, 45, 81, 232, 343, 545, 887, 999]
# [2, 3, 4, 5, 3, 1, 2, 4, 3, 6, 7, 4, 34, 45, 81, 232, 343, 545, 887, 999]
# [2, 3, 4, 3, 1, 2, 4, 3, 5, 6, 4, 7, 34, 45, 81, 232, 343, 545, 887, 999]
# [2, 3, 3, 1, 2, 4, 3, 4, 5, 4, 6, 7, 34, 45, 81, 232, 343, 545, 887, 999]
# [2, 3, 1, 2, 3, 3, 4, 4, 4, 5, 6, 7, 34, 45, 81, 232, 343, 545, 887, 999]
# [2, 1, 2, 3, 3, 3, 4, 4, 4, 5, 6, 7, 34, 45, 81, 232, 343, 545, 887, 999]
# [1, 2, 2, 3, 3, 3, 4, 4, 4, 5, 6, 7, 34, 45, 81, 232, 343, 545, 887, 999]
# [1, 2, 2, 3, 3, 3, 4, 4, 4, 5, 6, 7, 34, 45, 81, 232, 343, 545, 887, 999]
# ...
